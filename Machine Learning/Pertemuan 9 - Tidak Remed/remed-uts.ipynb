# %%
import numpy as np 
import pandas as pd 

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('Gizi-Balita.csv')
data.head()
# Out:
#    Usia (bulan)  Berat Badan (kg)  Tinggi Badan (cm)  Lingkar Kepala (cm)  \
# 0            40               8.3                108                 44.6
# 1            41              19.0                 61                 47.5
# 2            22              17.0                 69                 40.6
# 3            13              12.5                 96                 45.2
# 4            31              15.8                 68                 42.7
#
#    Lingkar Lengan Atas (cm) Jenis Kelamin Status Ekonomi Keluarga  \
# 0                      17.7     Perempuan                  Rendah
# 1                      16.3     Perempuan                  Rendah
# 2                      16.3     Perempuan                  Tinggi
# 3                      13.4     Perempuan                  Rendah
# 4                      16.5     Laki-laki                  Tinggi
#
#    Asupan Gizi Harian (kcal)    Riwayat Penyakit Tingkat Aktivitas Fisik  \
# ...

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data = data, x = 'Label Status Gizi', y = 'Asupan Gizi Harian (kcal)')
plt.title('Distribusi Asupan Gizi Harian Berdasarkan Status Gizi')
plt.xlabel('Label Status Gizi')
plt.ylabel('Asupan Gizi Harian (kcal)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
imunisasi_counts = data['Status Imunisasi'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(imunisasi_counts.values, labels=imunisasi_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Proporsi Status Imunisasi pada Balita')
plt.show()

# %%
# 5
plt.figure(figsize=(8,5))
plt.hist(data['Usia (bulan)'], color = 'skyblue', edgecolor = 'black')
plt.title('Distribusi Usia Balita')
plt.xlabel('Usia (Bulan)')
plt.ylabel('Jumlah Balita')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=data, x = 'Status Ekonomi Keluarga')
plt.title('Distribusi Status Ekonmi Keluarga')
plt.xlabel('Status Ekonomi')
plt.ylabel('Jumlah Balita')
plt.xticks(rotation=45, ha = 'right')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(data = data, x ='Label Status Gizi', hue = 'Status Imunisasi')
plt.title('Status Imunisasi Berdasarkan Status Gizi')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
X = 
y = data['Gizi']

# %%
model = KNeighborsClassifier()
